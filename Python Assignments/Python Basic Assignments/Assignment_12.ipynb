# %% [markdown]
# ## Assignment 12
#
# ### Q1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened
#
# **Ans:**

# %%
# STEP 1 : IMPORT THE PYPDF2 MODULE
# !pip install PyPDF2

# %% [markdown]
# The **PdfFileReader()** and **PdfFileWriter()** File objects should be opened in Read Binary Format & Write Binary Format

# %% [markdown]
# ### Q2. 2. From a PdfReader object, how do you get a Page object for page 5?
#
# **Ans:**

# %%
import PyPDF2

# %%
import PyPDF2

file_object = open('comp.pdf', 'rb')

# %%
from PyPDF2 import PdfReader

reader = PdfReader("comp.pdf")
number_of_pages = len(reader.pages)
page = reader.pages[5]
text = page.extract_text()

# %%
text
# Out:
# ' \n \n \n \n \nComputer Capsule– SBI,IBPS PO,RRB,CLRK  Mains Exam  \nw w w . m a k e m y e x a m . i n                     w w w . i b t i n d i a . c o m    \n Page 4  \nComputer memory is the storage space in computer where data is to be processed and instructions required for processing are \nstored.  \nPrimary Memory (Main Memory)- Primary memory holds only those data and instructions on which computer is currently \nworking. It has limited capacity and data is lost when power is switched off. It is generally made up of semiconductor device. \nThese memories are not as fast as registers. The data and instruction required to be processed reside in main memory. It is \ndivided into two subcategories RAM and ROM.  \nSecondary Memory(Auxiliary Memory) - This type of memory is also known a s external memory or non -volatile . It is \nslower than main memory. These are used for storing data/Information permanently. CPU directly does not access these \nmemories instead they are accesse
# ...

# %% [markdown]
# ### Q3. What PdfReader variable stores the number of pages in the PDF document?
#
# **Ans:**
#
# **len(reader.pages)**
#
#     Stores the number of pages in the integer form

# %%
print(f"No of Pages: {len(reader.pages)}")
print(f"Type: {type(len(reader.pages))}")
# Out:
# No of Pages: 137
# Type: <class 'int'>

# %% [markdown]
# ### Q4. If a PdfReader object’s PDF is encrypted with the password swordfish, what must you do before you can obtain Page objects from it?
#
# **Ans:**

# %%
file_object = open('comp.pdf', 'rb')
file = PdfReader(file_object)

print(f'Is my file Encrypted: {file.is_encrypted}')
# Out:
# Is my file Encrypted: False

# %% [markdown]
#     BUT If the PDF-file have some password ; It will return True
#     we can also decrypt it using the following command
#
#     To open a encrypted PDF file, it has to be decrypted using decrpyt('--password--')
#
#   **file.decrypt('swordfish')**

# %% [markdown]
# ### Q5 What methods do you use to rotate a page?
#
# **Ans:**

# %%
from PyPDF2 import PdfReader

reader = PdfReader("comp.pdf")
page = reader.pages[5]
page.rotate(90)
# Out:
# {'/Type': '/Page',
#  '/MediaBox': [0, 0, 612, 792],
#  '/Parent': {'/Type': '/Pages',
#   '/Count': 137,
#   '/Kids': [IndirectObject(4, 0, 2352589687632),
#    IndirectObject(52, 0, 2352589687632),
#    IndirectObject(70, 0, 2352589687632),
#    IndirectObject(120, 0, 2352589687632),
#    IndirectObject(139, 0, 2352589687632),
#    IndirectObject(146, 0, 2352589687632),
#    IndirectObject(150, 0, 2352589687632),
#    IndirectObject(153, 0, 2352589687632),
#    IndirectObject(158, 0, 2352589687632),
#    IndirectObject(170, 0, 2352589687632),
#    IndirectObject(174, 0, 2352589687632),
#    IndirectObject(181, 0, 2352589687632),
#    IndirectObject(185, 0, 2352589687632),
#    IndirectObject(187, 0, 2352589687632),
#    IndirectObject(190, 0, 2352589687632),
#    IndirectObject(195, 0, 2352589687632),
#    IndirectObject(198, 0, 2352589687632),
#    IndirectObject(202, 0, 2352589687632),
#    IndirectObject(206, 0, 2352589687632),
#    IndirectObject(211, 0, 2352589687632),
# ...

# %% [markdown]
# ### Q6. What is the difference between a Run object and a Paragraph object?
#
# **Ans:**  The structure of a document is represented by three different data types in **python-Docx**. At the highest level, a Document object represents the entire document. The Document object contains a list of **Paragraph objects** for the paragraphs in the document. (A new paragraph begins whenever the user presses ENTER or RETURN while typing in a Word document.) Each of these Paragraph objects contains a list of one or more **Run objects**.
#
# The text in a Word document is more than just a string. It has font, size, color, and other styling information associated with it. A style in Word is a collection of these attributes. A Run object is a contiguous run of text with the same style. A new Run object is needed whenever the text style changes.

# %% [markdown]
# ### Q7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable named doc?
# **Ans:**-

# %%
pip install python-docx
# Out:
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184600 sha256=bb01375b54ffae2c60e1dfe570699798ebfcfe8bb729da4e004854e257393a0a
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\32\b8\b2\c4c2b95765e615fe139b0b17b5ea7c0e1b6519b0a9ec8fb34d
# Successfully built python-docx
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Example Program
import docx

# %%
doc = docx.Document("test.docx") # Path of the Docx file

print(doc.paragraphs) # Prints the list of Paragraph objects for a Document

for paragraph in doc.paragraphs:
    print(paragraph.text) # Prints the text in the paragraph
# Out:
# [<docx.text.paragraph.Paragraph object at 0x000001AEBC292C40>, <docx.text.paragraph.Paragraph object at 0x000001AEBC300580>, <docx.text.paragraph.Paragraph object at 0x000001AEBC300B20>, <docx.text.paragraph.Paragraph object at 0x000001AEBC4B0B20>, <docx.text.paragraph.Paragraph object at 0x000001AEBC174F70>, <docx.text.paragraph.Paragraph object at 0x000001AEBC311970>, <docx.text.paragraph.Paragraph object at 0x000001AEBC2FB670>, <docx.text.paragraph.Paragraph object at 0x000001AEBC2FBC70>, <docx.text.paragraph.Paragraph object at 0x000001AEBC15FA00>, <docx.text.paragraph.Paragraph object at 0x000001AEBC237A60>, <docx.text.paragraph.Paragraph object at 0x000001AEBC18AC70>, <docx.text.paragraph.Paragraph object at 0x000001AEBC18A370>, <docx.text.paragraph.Paragraph object at 0x000001AEBC143430>, <docx.text.paragraph.Paragraph object at 0x000001AEBC2772E0>, <docx.text.paragraph.Paragraph object at 0x000001AEBC277160>, <docx.text.paragraph.Paragraph object at 0x000001AEBC039A30>, <docx
# ...

# %% [markdown]
# ### Q8. What type of object has bold, underline, italic, strike, and outline variables?
#
# **Ans:**
#
# **Run object** has bold, underline, italic, strike, and outline variables. The text in a Word document is more than just a string. It has font, size, color, and other styling information associated with it.
#
# A style in Word is a collection of these attributes. A Run object is a contiguous run of text with the same style. A new Run object is needed whenever the text style changes.

# %% [markdown]
# ### Q9. What is the difference between False, True, and None for the bold variable?
#
# **Ans:**
#
#     If the Bold variable is set to False, the variable is always disabled.
#     If the Bold variable is set to True, the variable is always enabled, no matter what other styles are applied to the run.
#     If the Bold variable is set to None, defaults to whatever the run’s style is set to.

# %% [markdown]
# ### Q10. How do you create a Document object for a new Word document?
#
# **Ans:**

# %%
from docx import Document
new_doc = Document()
new_doc.add_paragraph("iNeuron Full Stack Datascience Course")
new_doc.save('sample_test.docx')

# %% [markdown]
# ### Q11. How do you add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named doc?

# %%
import docx
new_doc = docx.Document()
new_doc.add_paragraph('Hello There!!!')
new_doc.save('sample_test.docx')

# %% [markdown]
# ### Q12. What integers represent the levels of headings available in Word documents?
#
# **Ans:** The levels for a heading in a word document can be specified by using the **level** attribute inside the **add_heading** method. There are a total of 5 levels statring for 0 t0 4. where level 0 makes a headline with the horizontal line below the text, whereas the heading level 1 is the main heading. Similarly, the other headings are sub-heading with their's font-sizes in decreasing order.

# %%
import docx
new_doc = docx.Document()

new_doc.add_heading('This is HEADING - 1',level=1)
new_doc.add_heading('This is HEADING - 2',level=2)
new_doc.add_heading('This is HEADING - 3',level=3)
new_doc.add_heading('This is HEADING - 4',level=4)
new_doc.add_heading('This is HEADING - 5',level=5)

new_doc.save('sample_test1.docx')
